# %% [markdown]
# ### Extracting Surfaces from subject MRIS

# %%
#### IMPORTING MODULES ####
import os
import mne
mne.viz.set_3d_backend("notebook")
from osl_dynamics.meeg import rhino

#--------------------------------------------------------------------------------------#

#### DEFINING SURFACE EXTRACTION FUNCTIONION ####

def surface_extraction(mrifile, outdirsurf):

    # rhino.extract_surfaces(
    #    mri_file = mrifile,
    #    outdir = outdirsurf,
    # )

    rhino.extract_surfaces(
    mri_file=mrifile,
    outdir=outdirsurf,
    include_nose=False,
    do_mri2mniaxes_xform=False,
    show=True,
    )

    return None

# %%
subjects = ["001"]

base = "/rdrives/DRS-foundation-brain/zoe_data/BIDS"
deriv = f"{base}/derivatives_anna_31032026"
surf_dir = f"{deriv}/anat_surfaces"
os.makedirs(deriv, exist_ok=True)

for subject in subjects:

    mri_file = (f"{base}/derivatives/FS_SUBJECTS/sub-{subject}/mri/T1.nii.gz")
    outdir_surf = (f"{surf_dir}/sub-{subject}")
    os.makedirs(outdir_surf, exist_ok=True)

    surface_extraction(mri_file, outdir_surf)
# Out:
# Extracting surfaces
# -------------------
# You can use the following command line call to check the MRI is appropriate, including checking that the L-R, S-I, A-P labels are sensible:
# fsleyes /rdrives/DRS-foundation-brain/zoe_data/BIDS/derivatives_anna_31032026/anat_surfaces/sub-001/smri.nii.gz /home/anna-beer/fsl/data/standard/MNI152_T1_1mm_brain.nii.gz
# Running BET pre-FLIRT...
# Running FLIRT...
# Running BET and BETSURF...
# Cleaning up FLIRT files
# Saving /rdrives/DRS-foundation-brain/zoe_data/BIDS/derivatives_anna_31032026/anat_surfaces/sub-001/inskull.png
# Saving /rdrives/DRS-foundation-brain/zoe_data/BIDS/derivatives_anna_31032026/anat_surfaces/sub-001/outskull.png
# Saving /rdrives/DRS-foundation-brain/zoe_data/BIDS/derivatives_anna_31032026/anat_surfaces/sub-001/outskin.png
# Surface extraction complete.
